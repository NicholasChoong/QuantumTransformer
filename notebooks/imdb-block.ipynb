# %% [markdown]
# # Transformers

# %%
import os
import sys

os.chdir("..")
sys.path.append(os.getcwd())
os.getcwd()
# Out:
# '/group/pmc026/nchoong/QuantumTransformer'

# %%
from transformer.pytorch.main_no_embed import main
from transformer.pytorch.utils.plots import plot_metrics
from transformer.pytorch.utils.load_dataloader import load_dataloader
# Out:
# 2024-10-07 09:14:40.038425: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-07 09:14:40.051194: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-07 09:14:40.066875: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-07 09:14:40.071681: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-07 09:14:40.083591: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-07 09:14:42.587628: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Please first ``pip install -U qiskit`` to enable related functionality in translation module

# %%
from config import dev

dev
# Out:
# device(type='cpu')

# %%
import random
import numpy as np
import torch
import tensorflow as tf

# %%
[torch.cuda.device(i) for i in range(torch.cuda.device_count())]
# Out:
# [<torch.cuda.device at 0x7f291b3be6d0>, <torch.cuda.device at 0x7f291c54b610>]

# %%
seed = 42

os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

os.environ["OMP_NUM_THREADS"] = str(os.cpu_count())
os.environ["TF_NUM_INTEROP_THREADS"] = str(os.cpu_count())
os.environ["TF_NUM_INTRAOP_THREADS"] = str(os.cpu_count())

tf.config.threading.set_intra_op_parallelism_threads(os.cpu_count())
tf.config.threading.set_inter_op_parallelism_threads(os.cpu_count())

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
train_dataloader, val_dataloader, test_dataloader = load_dataloader("imdb")
# Out:
# Loading train tensors: 100%|██████████| 7/7 [00:03<00:00,  2.30it/s]
# Sample size:  5000
# Loading val tensors: 100%|██████████| 2/2 [00:00<00:00,  2.65it/s]
# Loading test tensors: 100%|██████████| 9/9 [00:02<00:00,  3.01it/s]
# Test size:  5000
# Sampled train tensor shape:  torch.Size([20000, 128, 768])
# Sampled val tensor shape:  torch.Size([5000, 128, 768])
# Sampled test tensor shape:  torch.Size([5000, 128, 768])
# Train, Val, Test size:  20000 5000 5000
# pos:  10006
# neg:  9994
# pos:  2494
# neg:  2506
# pos:  2515
# neg:  2485

# %% [markdown]
# ## Classical

# %% [markdown]
# ## Quantum with Pennylane GPU

# %%
train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    test_dataloader=test_dataloader,
    n_epochs=20,
    sample_size=0,
    batch_size=64,
    embed_dim=2**4 * 2**4,
    num_heads=2,
    num_blocks=2,
    n_qubits_transformer=4,
    n_qubits_ffn=4,
    n_qlayers=3,
    tqdm_disabled=False,
    q_device="default.qubit",
    batch=True,
    circuit_type="pennylane",
    encoding_type="block",
    pennylane_args={
        "hadamard": False,
        "encoder": "angle",
        "angle_rot": "X",
        "entangler": "basic",
        "rot": "Z",
        "imprimitive": "Z",
    },
)

quantum_pl_gpu_metrics_batch = {
    "train_loss": train_loss,
    "train_acc": train_acc,
    "val_loss": val_loss,
    "val_acc": val_acc,
    "train_auc": train_auc,
    "val_auc": val_auc,
    "best_dict": best_dict,
}
# Out:
# ++ There will be 2 transformer blocks
# ++ Transformer will use 4 qubits and 3 q layers
# The feed-forward head will use 4 qubits
# Using PennyLane quantum device default.qubit
# weight_shapes = (n_qlayers, n_qubits) = (3, 4)
# weight_shapes = (n_qlayers, n_qubits) = (3, 4)
# TextClassifier(
#   (squeeze): Linear(in_features=768, out_features=256, bias=True)
#   (transformers): ModuleList(
#     (0-1): 2 x Encoder(
#       (attn): MultiHeadedAttention(
#         (k_linear): QuantumLayer(
#           (linear): <Quantum Torch Layer: func=qlayer>
#           (squeeze): Linear(in_features=5, out_features=4, bias=True)
#         )
#         (q_linear): QuantumLayer(
#           (linear): <Quantum Torch Layer: func=qlayer>
#           (squeeze): Linear(in_features=5, out_features=4, bias=True)
#         )
#         (v_linear): QuantumLayer(
#           (linear): <Quantum Torch Layer: func=qlayer>
#           (squeeze): Linear(in_features=5, out_features=4, bias=True)
#         )
#         (combine_heads): QuantumLayer(
#           (linear): <Quantum Torch Layer: func=qlayer>
#           (squeeze): Linear(in_features=5, out_features=4, bias=True)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#         (unsqueeze1): Linear(in_features=2, out_features=128, bias=True)
#         (unsqueeze2): Linear(in_features=4, out_features=256, bias=True)
#       )
#       (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (dropout1): Dropout(p=0.1, inplace=False)
#       (ffn): FeedForward(
#         (linear_1): Linear(in_features=256, out_features=4, bias=True)
#         (linear_2): Linear(in_features=4, out_features=256, bias=True)
#         (vqc): QuantumLayer(
#           (linear): <Quantum Torch Layer: func=qlayer>
#           (squeeze): Linear(in_features=5, out_features=4, bias=True)
#         )
#         (gelu): GELU(approximate='none')
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (dropout2): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (layer_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (class_logits): Linear(in_features=256, out_features=1, bias=True)
# )
# Layer Name                               Number of Parameters
# ============================================================
# squeeze.weight                           196608
# squeeze.bias                             256
# transformers.0.attn.k_linear.linear.weights 15
# transformers.0.attn.k_linear.squeeze.weight 20
# transformers.0.attn.k_linear.squeeze.bias 4
# transformers.0.attn.q_linear.linear.weights 15
# transformers.0.attn.q_linear.squeeze.weight 20
# transformers.0.attn.q_linear.squeeze.bias 4
# transformers.0.attn.v_linear.linear.weights 15
# transformers.0.attn.v_linear.squeeze.weight 20
# transformers.0.attn.v_linear.squeeze.bias 4
# transformers.0.attn.combine_heads.linear.weights 15
# transformers.0.attn.combine_heads.squeeze.weight 20
# transformers.0.attn.combine_heads.squeeze.bias 4
# transformers.0.attn.unsqueeze1.weight    256
# transformers.0.attn.unsqueeze1.bias      128
# transformers.0.attn.unsqueeze2.weight    1024
# transformers.0.attn.unsqueeze2.bias      256
# transformers.0.norm1.weight              256
# transformers.0.norm1.bias                256
# transformers.0.ffn.linear_1.weight       1024
# transformers.0.ffn.linear_1.bias         4
# transformers.0.ffn.linear_2.weight       1024
# transformers.0.ffn.linear_2.bias         256
# transformers.0.ffn.vqc.linear.weights    15
# transformers.0.ffn.vqc.squeeze.weight    20
# transformers.0.ffn.vqc.squeeze.bias      4
# transformers.0.norm2.weight              256
# transformers.0.norm2.bias                256
# transformers.1.attn.k_linear.linear.weights 15
# transformers.1.attn.k_linear.squeeze.weight 20
# transformers.1.attn.k_linear.squeeze.bias 4
# transformers.1.attn.q_linear.linear.weights 15
# transformers.1.attn.q_linear.squeeze.weight 20
# transformers.1.attn.q_linear.squeeze.bias 4
# transformers.1.attn.v_linear.linear.weights 15
# transformers.1.attn.v_linear.squeeze.weight 20
# transformers.1.attn.v_linear.squeeze.bias 4
# transformers.1.attn.combine_heads.linear.weights 15
# transformers.1.attn.combine_heads.squeeze.weight 20
# transformers.1.attn.combine_heads.squeeze.bias 4
# transformers.1.attn.unsqueeze1.weight    256
# transformers.1.attn.unsqueeze1.bias      128
# transformers.1.attn.unsqueeze2.weight    1024
# transformers.1.attn.unsqueeze2.bias      256
# transformers.1.norm1.weight              256
# transformers.1.norm1.bias                256
# transformers.1.ffn.linear_1.weight       1024
# transformers.1.ffn.linear_1.bias         4
# transformers.1.ffn.linear_2.weight       1024
# transformers.1.ffn.linear_2.bias         256
# transformers.1.ffn.vqc.linear.weights    15
# transformers.1.ffn.vqc.squeeze.weight    20
# transformers.1.ffn.vqc.squeeze.bias      4
# transformers.1.norm2.weight              256
# transformers.1.norm2.bias                256
# layer_norm.weight                        256
# layer_norm.bias                          256
# class_logits.weight                      256
# class_logits.bias                        1
# The model has 208,015 trainable parameters
# Epoch   1/20:   0%|          | 0/313 [00:00<?, ?batch/s]

# %%
plot_metrics(train_loss, val_loss, train_acc, val_acc, train_auc, val_auc)

# %%
train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
    train_dataloader=train_dataloader,
    val_dataloader=val_dataloader,
    test_dataloader=test_dataloader,
    n_epochs=20,
    sample_size=0,
    batch_size=64,
    embed_dim=256,
    num_heads=2,
    num_blocks=2,
    n_qubits_transformer=8,
    n_qubits_ffn=8,
    n_qlayers=3,
    tqdm_disabled=False,
    q_device="default.qubit.torch",
    batch=True,
    circuit_type="pennylane",
    encoding_type="block",
    pennylane_args={
        "hadamard": False,
        "encoder": "angle",
        "angle_rot": "X",
        "entangler": "strong",
        "rot": "Z",
        "imprimitive": "Z",
    },
)

quantum_pl_gpu_metrics_batch = {
    "train_loss": train_loss,
    "train_acc": train_acc,
    "val_loss": val_loss,
    "val_acc": val_acc,
    "train_auc": train_auc,
    "val_auc": val_auc,
    "best_dict": best_dict,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
#       2     train_dataloader=train_dataloader,
#       3     val_dataloader=val_dataloader,
#       4     test_dataloader=test_dataloader,
#       5     n_epochs=20,
#       6     sample_size=0,
#       7     batch_size=64,
#       8     embed_dim=8,
#       9     num_heads=2,
#      10     num_blocks=2,
#      11     n_qubits_transformer=8,
#      12     n_qubits_ffn=8,
#      13     n_qlayers=3,
#      14     tqdm_disabled=False,
#      15     q_device="default.qubit.torch",
#      16     batch=True,
#      17     circuit_type="pennylane",
#      18     encoding_type="block",
#      19     pennylane_args={
#      20         "hadamard": False,
#      21         "encoder": "angle",
#      22         "angle_rot": "X",
#      23         "entangler": "strong",
#      24         "rot": "X",
#      25         "imprimitive": "X",
#      26     },
#      27 )
#      29 quantum_pl_gpu_metrics_batch = {
#      30     "train_loss": train_loss,
#      31     "train_acc": train_acc,
#    (...)
#      36     "best_dict": best_dict,
#      37 }
#
# NameError: name 'main' is not defined

# %%
plot_metrics(train_loss, val_loss, train_acc, val_acc, train_auc, val_auc)
