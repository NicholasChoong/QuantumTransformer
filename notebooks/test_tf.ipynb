# %%
# import os
# from accelerate.utils import write_basic_config

# write_basic_config()  # Write a config file
# os._exit(00)  # Restart the notebook

# %%
import os
import sys

os.chdir("..")
sys.path.append(os.getcwd())
os.getcwd()
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# %%
from transformer.tensorflow.main import main
from transformer.tensorflow.utils.plots import plot_metrics
# Out:
# 2024-09-24 03:42:45.594791: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-24 03:42:45.608419: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-24 03:42:45.624254: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-24 03:42:45.629038: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-24 03:42:45.640781: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-24 03:42:47.789086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Please first ``pip install -U qiskit`` to enable related functionality in translation module

# %%
from config import dev

dev
# Out:
# device(type='cpu')

# %%
import random
import numpy as np
import tensorflow as tf

# %%
seed = 42

os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
tf.config.threading.set_inter_op_parallelism_threads(1)
tf.config.threading.set_intra_op_parallelism_threads(1)

os.environ["OMP_NUM_THREADS"] = str(os.cpu_count())
os.environ["TF_NUM_INTEROP_THREADS"] = str(os.cpu_count())
os.environ["TF_NUM_INTRAOP_THREADS"] = str(os.cpu_count())

tf.config.threading.set_intra_op_parallelism_threads(os.cpu_count())
tf.config.threading.set_inter_op_parallelism_threads(os.cpu_count())

# %%
# train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
#     n_epochs=30,
#     sample_size=5000,
#     batch_size=32,
#     embed_dim=8,
#     num_heads=2,
#     num_blocks=2,
#     tqdm_disabled=False,
#     batch=True,
# )

# classiscal_metrics = {
#     "train_loss": train_loss,
#     "train_acc": train_acc,
#     "val_loss": val_loss,
#     "val_acc": val_acc,
#     "train_auc": train_auc,
#     "val_auc": val_auc,
#     "best_dict": best_dict,
# }

# %%
# plot_metrics(train_loss, val_loss, train_acc, val_acc, train_auc, val_auc)

# %%
# train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
#     n_epochs=3,
#     sample_size=5000,
#     batch_size=32,
#     embed_dim=8,
#     num_heads=2,
#     num_blocks=2,
#     n_qubits_transformer=8,
#     n_qubits_ffn=8,
#     n_qlayers=3,
#     tqdm_disabled=False,
#     q_device="default.qubit",
#     circuit_type="pennylane",
# )

# quantum_pl_gpu_metrics = {
#     "train_loss": train_loss,
#     "train_acc": train_acc,
#     "val_loss": val_loss,
#     "val_acc": val_acc,
#     "train_auc": train_auc,
#     "val_auc": val_auc,
#     "best_dict": best_dict,
# }
# Out:
# 2024-09-24 03:43:04.567283: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-24 03:43:04.567449: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2024-09-24 03:43:04.568153: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-24 03:43:04.568383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 31134 MB memory:  -> device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:d8:00.0, compute capability: 7.0
# pos:  1979
# neg:  2021
# pos:  505
# neg:  495
# pos:  1265
# neg:  1235
# (128, 768)
# ++ There will be 2 transformer blocks
# ++ Transformer will use 8 qubits and 3 q layers
# The feed-forward head will use 8 qubits
# Using PennyLane quantum device default.qubit
# The model has 240 trainable parameters
# Epoch   1/3:   0%|          | 0/4000 [06:34<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
#       2     n_epochs=3,
#       3     sample_size=5000,
#       4     batch_size=32,
#       5     embed_dim=8,
#       6     num_heads=2,
#       7     num_blocks=2,
#       8     n_qubits_transformer=8,
#       9     n_qubits_ffn=8,
#      10     n_qlayers=3,
#      11     tqdm_disabled=False,
#      12     q_device="default.qubit",
#      13     circuit_type="pennylane",
#      14 )
#      16 quantum_pl_gpu_metrics = {
#      17     "train_loss": train_loss,
#      18     "train_acc": train_acc,
#    (...)
#      23     "best_dict": best_dict,
#      24 }
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/main.py:173, in main(dataset_name, max_seq_len, batch_size, sample_size, n_epochs, lr, embed_dim, num_heads, num_blocks, num_classes, vocab_size, ffn_dim, n_qubits_transformer, n_qubits_ffn, n_qlayers, dropout_rate, tqdm_disabled, q_device, batch, circuit_type)
#     164 with tqdm(
#     165     total=len(train_data),
#     166     desc=f"Epoch {iepoch+1:3}/{n_epochs}",
#    (...)
#     169     disable=tqdm_disabled,
#     170 ) as progress_bar:
#     171     operation_start_time = time()
# --> 173     train_loss, train_acc, train_auc = train(
#     174         model,
#     175         train_dataset,
#     176         optimizer,
#     177         criterion,
#     178         lr_schedule,
#     179         max_seq_len,
#     180         batch_size,
#     181         progress_bar,
#     182     )
#     184     val_loss, val_acc, val_auc = evaluate(
#     185         model, val_dataset, criterion, max_seq_len
#     186     )
#     188     end_time = time()
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/utils/train.py:29, in train(model, dataset, optimizer, criterion, scheduler, max_seq_len, batch_size, progress_bar)
#      26 input = tf.convert_to_tensor(input)
#      27 lab = tf.convert_to_tensor(lab)
# ---> 29 predictions = tf.squeeze(model(input), axis=1)
#      31 # Calculate loss
#      32 loss = criterion(lab, predictions)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/training.py:588, in Model.__call__(self, *args, **kwargs)
#     584         super().__call__(inputs, *copied_args, **copied_kwargs)
#     586     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 588 return super().__call__(*args, **kwargs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/base_layer.py:1136, in Layer.__call__(self, *args, **kwargs)
#    1131     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1133 with autocast_variable.enable_auto_cast_variables(
#    1134     self._compute_dtype_object
#    1135 ):
# -> 1136     outputs = call_fn(inputs, *args, **kwargs)
#    1138 if self._activity_regularizer:
#    1139     self._handle_activity_regularization(inputs, outputs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/text_classifier.py:82, in TextClassifier.call(self, x, training)
#      79 x = self.squeeze(x)
#      81 for transformer in self.transformers:
# ---> 82     x = transformer(x)
#      84 x = tf.reduce_mean(x, axis=1)  # global average pooling, works in 1D
#      85 x = self.dropout(x, training=training)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/training.py:588, in Model.__call__(self, *args, **kwargs)
#     584         super().__call__(inputs, *copied_args, **copied_kwargs)
#     586     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 588 return super().__call__(*args, **kwargs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/base_layer.py:1136, in Layer.__call__(self, *args, **kwargs)
#    1131     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1133 with autocast_variable.enable_auto_cast_variables(
#    1134     self._compute_dtype_object
#    1135 ):
# -> 1136     outputs = call_fn(inputs, *args, **kwargs)
#    1138 if self._activity_regularizer:
#    1139     self._handle_activity_regularization(inputs, outputs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/quantum/encoder.py:63, in Encoder.call(self, x)
#      61 def call(self, x):
#      62     # Multi-head attention with residual connection and normalization
# ---> 63     attn_output = self.attn(x, x, x)
#      64     x = self.norm1(attn_output + x)
#      65     x = self.dropout1(x)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/base_layer.py:1136, in Layer.__call__(self, *args, **kwargs)
#    1131     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1133 with autocast_variable.enable_auto_cast_variables(
#    1134     self._compute_dtype_object
#    1135 ):
# -> 1136     outputs = call_fn(inputs, *args, **kwargs)
#    1138 if self._activity_regularizer:
#    1139     self._handle_activity_regularization(inputs, outputs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/quantum/multihead.py:59, in MultiHeadedAttention.call(self, query, key, value)
#      53 embed_dim = tf.shape(query)[2]
#      55 assert (
#      56     embed_dim == self.embed_dim
#      57 ), f"Input embedding ({embed_dim}) does not match layer embedding size ({self.embed_dim})"
# ---> 59 Q, K, V = [
#      60     tf.reshape(linear(x), (batch_size, seq_len, self.num_heads, self.dim_k))
#      61     for linear, x in zip(
#      62         [self.k_linear, self.q_linear, self.v_linear], [key, query, value]
#      63     )
#      64 ]
#      66 Q, K, V = [tf.transpose(tensor, perm=[0, 2, 1, 3]) for tensor in [Q, K, V]]
#      68 # Apply attention (assuming a custom attention function exists)
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/quantum/multihead.py:60, in <listcomp>(.0)
#      53 embed_dim = tf.shape(query)[2]
#      55 assert (
#      56     embed_dim == self.embed_dim
#      57 ), f"Input embedding ({embed_dim}) does not match layer embedding size ({self.embed_dim})"
#      59 Q, K, V = [
# ---> 60     tf.reshape(linear(x), (batch_size, seq_len, self.num_heads, self.dim_k))
#      61     for linear, x in zip(
#      62         [self.k_linear, self.q_linear, self.v_linear], [key, query, value]
#      63     )
#      64 ]
#      66 Q, K, V = [tf.transpose(tensor, perm=[0, 2, 1, 3]) for tensor in [Q, K, V]]
#      68 # Apply attention (assuming a custom attention function exists)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/base_layer.py:1136, in Layer.__call__(self, *args, **kwargs)
#    1131     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1133 with autocast_variable.enable_auto_cast_variables(
#    1134     self._compute_dtype_object
#    1135 ):
# -> 1136     outputs = call_fn(inputs, *args, **kwargs)
#    1138 if self._activity_regularizer:
#    1139     self._handle_activity_regularization(inputs, outputs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/quantum/_pennylane.py:34, in QuantumLayer.call(self, inputs)
#      32 shape = inputs.shape
#      33 x = tf.reshape(inputs, [-1, shape[-1]])
# ---> 34 x = [self.linear(embed) for embed in x]
#      35 # x = tf.cast(x, tf.float64)
#      36 # print(self.linear(x[0]))
#      37 # x = tf.map_fn(self.linear, x, fn_output_signature=tf.float64)
#      38 # for i, embed in enumerate(x):
#      39 #     print(i)
#      40 #     self.linear(embed)
#      41 x = tf.concat(x, axis=-1)
#
# File /group/pmc026/nchoong/QuantumTransformer/transformer/tensorflow/quantum/_pennylane.py:34, in <listcomp>(.0)
#      32 shape = inputs.shape
#      33 x = tf.reshape(inputs, [-1, shape[-1]])
# ---> 34 x = [self.linear(embed) for embed in x]
#      35 # x = tf.cast(x, tf.float64)
#      36 # print(self.linear(x[0]))
#      37 # x = tf.map_fn(self.linear, x, fn_output_signature=tf.float64)
#      38 # for i, embed in enumerate(x):
#      39 #     print(i)
#      40 #     self.linear(embed)
#      41 x = tf.concat(x, axis=-1)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/engine/base_layer.py:1136, in Layer.__call__(self, *args, **kwargs)
#    1131     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1133 with autocast_variable.enable_auto_cast_variables(
#    1134     self._compute_dtype_object
#    1135 ):
# -> 1136     outputs = call_fn(inputs, *args, **kwargs)
#    1138 if self._activity_regularizer:
#    1139     self._handle_activity_regularization(inputs, outputs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tf_keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/pennylane/qnn/keras.py:414, in KerasLayer.call(self, inputs)
#     411     inputs = tf.reshape(inputs, (-1, inputs.shape[-1]))
#     413 # calculate the forward pass as usual
# --> 414 results = self._evaluate_qnode(inputs)
#     416 # reshape to the correct number of batch dims
#     417 if has_batch_dim:
#     418     # pylint:disable=unexpected-keyword-arg,no-value-for-parameter
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/pennylane/qnn/keras.py:445, in KerasLayer._evaluate_qnode(self, x)
#     442         res = [tf.reshape(r, (tf.shape(x)[0], tf.reduce_prod(r.shape[1:]))) for r in res]
#     444     # multi-return and no batch dim
# --> 445     return tf.experimental.numpy.hstack(res)
#     447 return res
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/numpy_ops/np_array_ops.py:1217, in hstack(tup)
#    1214 @tf_export.tf_export('experimental.numpy.hstack', v1=[])
#    1215 @np_utils.np_doc('hstack')
#    1216 def hstack(tup):
# -> 1217   arrays = [atleast_1d(a) for a in tup]
#    1218   arrays = _promote_dtype(*arrays)  # pylint: disable=protected-access
#    1219   unwrapped_arrays = [
#    1220       a if isinstance(a, np_arrays.ndarray) else a for a in arrays
#    1221   ]
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/numpy_ops/np_array_ops.py:1217, in <listcomp>(.0)
#    1214 @tf_export.tf_export('experimental.numpy.hstack', v1=[])
#    1215 @np_utils.np_doc('hstack')
#    1216 def hstack(tup):
# -> 1217   arrays = [atleast_1d(a) for a in tup]
#    1218   arrays = _promote_dtype(*arrays)  # pylint: disable=protected-access
#    1219   unwrapped_arrays = [
#    1220       a if isinstance(a, np_arrays.ndarray) else a for a in arrays
#    1221   ]
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/numpy_ops/np_array_ops.py:1296, in atleast_1d(*arys)
#    1293 @tf_export.tf_export('experimental.numpy.atleast_1d', v1=[])
#    1294 @np_utils.np_doc('atleast_1d')
#    1295 def atleast_1d(*arys):
# -> 1296   return _atleast_nd(1, _pad_left_to, *arys)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/numpy_ops/np_array_ops.py:1286, in _atleast_nd(n, new_shape, *arys)
#    1277   x = asarray(x)
#    1278   return asarray(
#    1279       np_utils.cond(
#    1280           np_utils.greater(n, array_ops.rank(x)),
#    (...)
#    1283       )
#    1284   )
# -> 1286 arys = list(map(f, arys))
#    1287 if len(arys) == 1:
#    1288   return arys[0]
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/numpy_ops/np_array_ops.py:1280, in _atleast_nd.<locals>.f(x)
#    1275 def f(x):
#    1276   # pylint: disable=g-long-lambda
#    1277   x = asarray(x)
#    1278   return asarray(
#    1279       np_utils.cond(
# -> 1280           np_utils.greater(n, array_ops.rank(x)),
#    1281           lambda: reshape(x, new_shape(n, array_ops.shape(x))),
#    1282           lambda: x,
#    1283       )
#    1284   )
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/array_ops.py:910, in rank(input, name)
#     877 @tf_export("rank")
#     878 @dispatch.add_dispatch_support
#     879 def rank(input, name=None):
#     880   # pylint: disable=redefined-builtin
#     881   """Returns the rank of a tensor.
#     882
#     883   See also `tf.shape`.
#    (...)
#     908   @end_compatibility
#     909   """
# --> 910   return rank_internal(input, name, optimize=True)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/ops/array_ops.py:933, in rank_internal(input, name, optimize)
#     931 input_shape = input.get_shape()
#     932 if optimize and input_shape.ndims is not None:
# --> 933   return constant(input_shape.ndims, dtypes.int32, name=name)
#     934 return gen_array_ops.rank(input, name=name)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:289, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     287     with trace.Trace("tf.constant"):
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File /group/pmc026/nchoong/qt_tf/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:297, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     291   const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292       value, dtype, shape, name, verify_shape, allow_broadcast
#     293   )
#     294   return const_tensor
# --> 297 def _constant_eager_impl(
#     298     ctx, value, dtype, shape, verify_shape
#     299 ) -> ops._EagerTensorBase:
#     300   """Creates a constant on the current device."""
#     301   t = convert_to_eager_tensor(value, ctx, dtype)
#
# KeyboardInterrupt:

# %%
# plot_metrics(train_loss, val_loss, train_acc, val_acc, train_auc, val_auc)

# %%
train_loss, train_acc, val_loss, val_acc, train_auc, val_auc, best_dict = main(
    n_epochs=4,
    sample_size=5000,
    batch_size=64,
    embed_dim=8,
    num_heads=2,
    num_blocks=2,
    n_qubits_transformer=8,
    n_qubits_ffn=8,
    n_qlayers=3,
    tqdm_disabled=False,
    batch=True,
    circuit_type="tensorcircuit",
)
# Out:
# 2024-09-24 01:51:47.255401: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-24 01:51:47.255579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31134 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2024-09-24 01:51:47.256302: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-09-24 01:51:47.256509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 31134 MB memory:  -> device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:d8:00.0, compute capability: 7.0
# pos:  1979
# neg:  2021
# pos:  505
# neg:  495
# pos:  1265
# neg:  1235
# (128, 768)
# ++ There will be 2 transformer blocks
# ++ Transformer will use 8 qubits and 3 q layers
# The feed-forward head will use 8 qubits
# Using TensorCircuit
# weight_shapes = (n_qlayers, n_qubits) = (3, 8)
# weight_shapes = (n_qlayers, n_qubits) = (3, 8)
# The model has 240 trainable parameters
# Epoch   1/10:   0%|          | 0/4000 [00:00<?, ?batch/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowBackend.vmap.<locals>.wrapper at 0x7f78a0524fe0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowBackend.vmap.<locals>.wrapper at 0x7f78a0525a80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1727114033.417355  475980 service.cc:146] XLA service 0x5709b050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1727114033.417393  475980 service.cc:154]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# I0000 00:00:1727114033.417476  475980 service.cc:154]   StreamExecutor device (1): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2024-09-24 01:53:53.451430: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-24 01:53:53.523432: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# I0000 00:00:1727114033.639995  475980 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f77103eb1a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f77103eb1a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch   1/10: 100%|██████████| 4000/4000 [02:37<00:00, 78.69batch/s]2024-09-24 01:54:48.345009: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch   1/10: 100%|██████████| 4000/4000 [02:50<00:00, 78.69batch/s]2024-09-24 01:56:07.628162: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch   1/10: 100%|██████████| 4000/4000 [03:56<00:00, 16.91batch/s, Epoch = 3m 56s, Loss = 0.6542|0.5464, Acc = 0.616|0.747, AUC = 66.858|83.640]
# Epoch   2/10: 100%|██████████| 4000/4000 [00:54<00:00, 76.86batch/s]2024-09-24 01:57:06.583069: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch   2/10: 100%|██████████| 4000/4000 [00:58<00:00, 67.85batch/s, Epoch = 0m 58s, Loss = 0.5038|0.5372, Acc = 0.767|0.731, AUC = 84.595|85.871]
# Epoch   3/10: 100%|██████████| 4000/4000 [00:57<00:00, 69.02batch/s, Epoch = 0m 57s, Loss = 0.4521|0.4637, Acc = 0.801|0.763, AUC = 87.628|87.126]
# Epoch   4/10: 100%|██████████| 4000/4000 [00:52<00:00, 74.58batch/s]2024-09-24 01:59:01.427444: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch   4/10: 100%|██████████| 4000/4000 [00:56<00:00, 70.32batch/s, Epoch = 0m 56s, Loss = 0.4326|0.4662, Acc = 0.810|0.780, AUC = 88.484|87.579]
# Epoch   5/10: 100%|██████████| 4000/4000 [00:58<00:00, 68.73batch/s, Epoch = 0m 58s, Loss = 0.4130|0.4676, Acc = 0.819|0.780, AUC = 89.508|88.027]
# Epoch   6/10: 100%|██████████| 4000/4000 [00:58<00:00, 68.69batch/s, Epoch = 0m 58s, Loss = 0.3951|0.4299, Acc = 0.828|0.793, AUC = 90.545|88.231]
# Epoch   7/10: 100%|██████████| 4000/4000 [00:57<00:00, 70.16batch/s, Epoch = 0m 57s, Loss = 0.3902|0.4370, Acc = 0.831|0.791, AUC = 90.784|88.178]
# Epoch   8/10: 100%|██████████| 4000/4000 [00:53<00:00, 70.45batch/s]2024-09-24 02:02:52.520393: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch   8/10: 100%|██████████| 4000/4000 [00:57<00:00, 69.40batch/s, Epoch = 0m 57s, Loss = 0.3880|0.4257, Acc = 0.833|0.801, AUC = 90.882|88.359]
# Epoch   9/10: 100%|██████████| 4000/4000 [00:58<00:00, 68.64batch/s, Epoch = 0m 58s, Loss = 0.3869|0.4427, Acc = 0.832|0.790, AUC = 90.915|88.259]
# Epoch  10/10: 100%|██████████| 4000/4000 [00:56<00:00, 70.39batch/s, Epoch = 0m 56s, Loss = 0.3875|0.4333, Acc = 0.832|0.791, AUC = 90.868|88.387]
# TOTAL TIME = 756.96s
# BEST ACC = 0.80% AT EPOCH 8
# BEST AUC = 88.39 AT EPOCH 10
# {'train_loss': [0.65420455,
#   0.5037588,
#   0.45210728,
#   0.4326297,
#   0.41304794,
#   0.395064,
#   0.39023727,
#   0.3880135,
#   0.38690728,
#   0.3875369],
#  'train_acc': [0.61625,
#   0.767,
#   0.80075,
#   0.80975,
#   0.819,
#   0.82775,
#   0.83075,
#   0.83325,
#   0.8325,
#   0.83225],
#  'val_loss': [0.5464064,
#   0.53716195,
#   0.4636773,
#   0.46616358,
#   0.46757385,
#   0.42985123,
#   0.43701628,
#   0.42568994,
#   0.4427433,
#   0.4333213],
#  'val_acc': [0.7470703,
#   0.7314453,
#   0.7626953,
#   0.78027344,
#   0.78027344,
#   0.79296875,
#   0.7910156,
#   0.80078125,
#   0.79003906,
#   0.7910156],
#  'train_auc': [66.85778357063865,
#   84.59520162097871,
#   87.62768595237624,
#   88.48370532851246,
#   89.50799325625651,
#   90.54490757606025,
#   90.78433397282049,
#   90.88166970408487,
#   90.91529841164989,
#   90.86789318522368],
#  'val_auc': [83.63956395639562,
#   85.87058705870587,
#   87.12631263126313,
#   87.57875787578757,
#   88.02720272027203,
#   88.23122312231224,
#   88.17841784178417,
#   88.35883588358836,
#   88.25882588258825,
#   88.38683868386839],
#  'best_dict': {'best_val_acc': 0.80078125,
#   'best_epoch_acc': 8,
#   'best_val_auc': 88.38683868386839,
#   'best_epoch_auc': 10}}

# %%
# plot_metrics(train_loss, val_loss, train_acc, val_acc, train_auc, val_auc)
