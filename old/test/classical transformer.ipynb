# %%
import os
import sys

os.chdir("..")
sys.path.append(os.getcwd())
os.getcwd()
# Out:
# '/Users/nicholaschoong/Documents/QuantumTransformer'

# %%
from text_classifier.main import main

# %%
from config import dev

dev
# Out:
# device(type='mps')

# %%
train_loss, train_acc, test_loss, test_acc = main()
# Out:
# pos:  12500
# neg:  12500
# ++ There will be 1 transformer blocks
# The model has 160,441 trainable parameters
# Epoch 1/20
# Epoch: 01 | Epoch Time: 0m 17s
# 	Train Loss: 0.693 | Train Acc: 51.85%
# 	 Test Loss: 0.687 |  Test Acc: 55.09%
# Epoch 2/20
# Epoch: 02 | Epoch Time: 0m 15s
# 	Train Loss: 0.666 | Train Acc: 58.32%
# 	 Test Loss: 0.621 |  Test Acc: 65.25%
# Epoch 3/20
# Epoch: 03 | Epoch Time: 0m 15s
# 	Train Loss: 0.589 | Train Acc: 68.55%
# 	 Test Loss: 0.575 |  Test Acc: 69.90%
# Epoch 4/20
# Epoch: 04 | Epoch Time: 0m 15s
# 	Train Loss: 0.538 | Train Acc: 72.77%
# 	 Test Loss: 0.550 |  Test Acc: 72.01%
# Epoch 5/20
# Epoch: 05 | Epoch Time: 0m 16s
# 	Train Loss: 0.501 | Train Acc: 75.77%
# 	 Test Loss: 0.545 |  Test Acc: 72.80%
# Epoch 6/20
# Epoch: 06 | Epoch Time: 0m 15s
# 	Train Loss: 0.474 | Train Acc: 77.50%
# 	 Test Loss: 0.518 |  Test Acc: 74.65%
# Epoch 7/20
# Epoch: 07 | Epoch Time: 0m 16s
# 	Train Loss: 0.453 | Train Acc: 78.95%
# 	 Test Loss: 0.513 |  Test Acc: 75.24%
# Epoch 8/20
# Epoch: 08 | Epoch Time: 0m 16s
# 	Train Loss: 0.429 | Train Acc: 80.54%
# 	 Test Loss: 0.524 |  Test Acc: 74.96%
# Epoch 9/20
# Epoch: 09 | Epoch Time: 0m 16s
# 	Train Loss: 0.413 | Train Acc: 81.49%
# 	 Test Loss: 0.523 |  Test Acc: 75.63%
# Epoch 10/20
# Epoch: 10 | Epoch Time: 0m 16s
# 	Train Loss: 0.395 | Train Acc: 82.34%
# 	 Test Loss: 0.510 |  Test Acc: 76.37%
# Epoch 11/20
# Epoch: 11 | Epoch Time: 0m 15s
# 	Train Loss: 0.383 | Train Acc: 83.32%
# 	 Test Loss: 0.521 |  Test Acc: 75.92%
# Epoch 12/20
# Epoch: 12 | Epoch Time: 0m 15s
# 	Train Loss: 0.365 | Train Acc: 84.18%
# 	 Test Loss: 0.528 |  Test Acc: 76.32%
# Epoch 13/20
# Epoch: 13 | Epoch Time: 0m 15s
# 	Train Loss: 0.354 | Train Acc: 84.86%
# 	 Test Loss: 0.531 |  Test Acc: 76.19%
# Epoch 14/20
# Epoch: 14 | Epoch Time: 0m 15s
# 	Train Loss: 0.340 | Train Acc: 85.65%
# 	 Test Loss: 0.546 |  Test Acc: 76.07%
# Epoch 15/20
# Epoch: 15 | Epoch Time: 0m 15s
# 	Train Loss: 0.328 | Train Acc: 86.21%
# 	 Test Loss: 0.552 |  Test Acc: 76.17%
# Epoch 16/20
# Epoch: 16 | Epoch Time: 0m 15s
# 	Train Loss: 0.320 | Train Acc: 86.47%
# 	 Test Loss: 0.548 |  Test Acc: 76.53%
# Epoch 17/20
# Epoch: 17 | Epoch Time: 0m 15s
# 	Train Loss: 0.310 | Train Acc: 87.24%
# 	 Test Loss: 0.569 |  Test Acc: 75.75%
# Epoch 18/20
# Epoch: 18 | Epoch Time: 0m 15s
# 	Train Loss: 0.298 | Train Acc: 87.56%
# 	 Test Loss: 0.592 |  Test Acc: 75.75%
# Epoch 19/20
# Epoch: 19 | Epoch Time: 0m 15s
# 	Train Loss: 0.289 | Train Acc: 88.04%
# 	 Test Loss: 0.598 |  Test Acc: 75.74%
# Epoch 20/20
# Epoch: 20 | Epoch Time: 0m 15s
# 	Train Loss: 0.282 | Train Acc: 88.42%
# 	 Test Loss: 0.605 |  Test Acc: 75.65%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# plt.style.use("classic")
# plt.style.use("dark_background")

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, "b-", label="Train Loss")
plt.plot(epochs, test_loss, "r-", label="Test Loss")
plt.title("Train and Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, "b-", label="Train Accuracy")
plt.plot(epochs, test_acc, "r-", label="Test Accuracy")
plt.title("Train and Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
