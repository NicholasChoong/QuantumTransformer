# %%
import os
import sys

os.chdir("..")
sys.path.append(os.getcwd())
os.getcwd()
# Out:
# 'c:\\web-dev\\QuantumTransformer'

# %%
from text_classifier.main import main

# %%
from config import dev

dev
# Out:
# device(type='cuda')

# %%
train_loss, train_acc, test_loss, test_acc = main(
    n_epochs=10,
    embed_dim=4,
    n_qubits_transformer=4,
    n_qubits_ffn=4,
    n_qlayers=2,
    num_blocks=1,
    num_heads=1,
    q_device="default.qubit.torch",
)
# Out:
# pos:  1616
# neg:  1584
# ++ There will be 1 transformer blocks
# ++ Transformer will use 4 qubits and 2 q layers
# The feed-forward head will use 4 qubits
# Using quantum device default.qubit.torch
# weight_shapes = (n_qlayers, n_qubits) = (2, 4)
# The model has 200,101 trainable parameters
# Epoch   1/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 1/10
# Epoch: 01 | Epoch Time: 22m 46s
# 	Train Loss: 0.756 | Train Acc: 49.50%
# 	Test Loss: 0.723 |  Test Acc: 51.31%
# Epoch   2/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 2/10
# Epoch: 02 | Epoch Time: 21m 51s
# 	Train Loss: 0.713 | Train Acc: 50.09%
# 	Test Loss: 0.698 |  Test Acc: 50.34%
# Epoch   3/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 3/10
# Epoch: 03 | Epoch Time: 21m 33s
# 	Train Loss: 0.699 | Train Acc: 49.78%
# 	Test Loss: 0.694 |  Test Acc: 51.81%
# Epoch   4/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 4/10
# Epoch: 04 | Epoch Time: 21m 34s
# 	Train Loss: 0.694 | Train Acc: 50.81%
# 	Test Loss: 0.697 |  Test Acc: 48.84%
# Epoch   5/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 5/10
# Epoch: 05 | Epoch Time: 21m 29s
# 	Train Loss: 0.694 | Train Acc: 51.41%
# 	Test Loss: 0.696 |  Test Acc: 51.38%
# Epoch   6/10:   0%|          | 0/3200 [00:00<?, ?batch/s]
# Epoch 6/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_loss, train_acc, test_loss, test_acc = main(
#       2     n_epochs=10,
#       3     embed_dim=4,
#       4     n_qubits_transformer=4,
#       5     n_qubits_ffn=4,
#       6     n_qlayers=2,
#       7     num_blocks=1,
#       8     num_heads=1,
#       9     q_device="default.qubit.torch",
#      10 )
#
# File c:\web-dev\QuantumTransformer\text_classifier\main.py:139, in main(max_seq_len, batch_size, total_size, n_epochs, lr, embed_dim, num_heads, num_blocks, num_classes, vocab_size, ffn_dim, n_qubits_transformer, n_qubits_ffn, n_qlayers, q_device, dropout_rate)
#     136 operation_start_time = time()
#     138 print(f"Epoch {iepoch+1}/{n_epochs}")
# --> 139 train_loss, train_acc = train(
#     140     model, train_loader, optimizer, criterion, max_seq_len, progress_bar
#     141 )
#     142 # GPUtil.showUtilization()
#     144 test_loss, test_acc = evaluate(model, test_loader, criterion, max_seq_len)
#
# File c:\web-dev\QuantumTransformer\lib\train.py:35, in train(model, dataloader, optimizer, criterion, max_seq_len, progress_bar)
#      33     inputs = inputs[:, :max_seq_len]
#      34 model.to(dev)
# ---> 35 predictions = model(inputs).squeeze(1)
#      37 label = lab.to(dev)
#      38 # label = label.unsqueeze(1)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\web-dev\QuantumTransformer\text_classifier\text_classifier.py:85, in TextClassifier.forward(self, x)
#      76 # # Normalise the data to range [0, 2*pi]
#      77 # min_val = x.min()
#      78 # max_val = x.max()
#    (...)
#      81
#      82 # print(f"Minimum value: {x.min()}, Maximum value: {x.max()}")
#      84 for transformer in self.transformers:
# ---> 85     x = transformer(x)
#      87 x = x.mean(dim=1)  # global average pooling, works in 1D
#      88 x = self.dropout(x)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\web-dev\QuantumTransformer\quantum\encoder.py:51, in Encoder.forward(self, x)
#      50 def forward(self, x: Tensor):
# ---> 51     attn_output = self.attn(x, x, x)
#      52     x = self.norm1(attn_output + x)
#      53     x = self.dropout1(x)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\web-dev\QuantumTransformer\quantum\multihead.py:80, in MultiHeadedAttention.forward(self, query, key, value, mask)
#      77 x, self.attn_weights = attention(Q, K, V, mask=mask, dropout=self.dropout)
#      78 x = x.transpose(1, 2).contiguous().view(batch_size, -1, embed_dim)
# ---> 80 output = [self.combine_heads(x[:, t, :]) for t in range(seq_len)]
#      81 output = torch.Tensor(pad_sequence(output))
#      82 return output
#
# File c:\web-dev\QuantumTransformer\quantum\multihead.py:80, in <listcomp>(.0)
#      77 x, self.attn_weights = attention(Q, K, V, mask=mask, dropout=self.dropout)
#      78 x = x.transpose(1, 2).contiguous().view(batch_size, -1, embed_dim)
# ---> 80 output = [self.combine_heads(x[:, t, :]) for t in range(seq_len)]
#      81 output = torch.Tensor(pad_sequence(output))
#      82 return output
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\qnn\torch.py:402, in TorchLayer.forward(self, inputs)
#     399     inputs = torch.reshape(inputs, (-1, inputs.shape[-1]))
#     401 # calculate the forward pass as usual
# --> 402 results = self._evaluate_qnode(inputs)
#     404 # reshape to the correct number of batch dims
#     405 if has_batch_dim:
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\qnn\torch.py:423, in TorchLayer._evaluate_qnode(self, x)
#     411 """Evaluates the QNode for a single input datapoint.
#     412
#     413 Args:
#    (...)
#     417     tensor: output datapoint
#     418 """
#     419 kwargs = {
#     420     **{self.input_arg: x},
#     421     **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     422 }
# --> 423 res = self.qnode(**kwargs)
#     425 if isinstance(res, torch.Tensor):
#     426     return res.type(x.dtype)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\workflow\qnode.py:1048, in QNode.__call__(self, *args, **kwargs)
#    1043         full_transform_program._set_all_argnums(
#    1044             self, args, kwargs, argnums
#    1045         )  # pylint: disable=protected-access
#    1047 # pylint: disable=unexpected-keyword-arg
# -> 1048 res = qml.execute(
#    1049     (self._tape,),
#    1050     device=self.device,
#    1051     gradient_fn=self.gradient_fn,
#    1052     interface=self.interface,
#    1053     transform_program=full_transform_program,
#    1054     config=config,
#    1055     gradient_kwargs=self.gradient_kwargs,
#    1056     override_shots=override_shots,
#    1057     **self.execute_kwargs,
#    1058 )
#    1060 res = res[0]
#    1062 # convert result to the interface in case the qfunc has no parameters
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\workflow\execution.py:684, in execute(tapes, device, gradient_fn, interface, transform_program, config, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform, device_vjp)
#     682 # Exiting early if we do not need to deal with an interface boundary
#     683 if no_interface_boundary_required:
# --> 684     results = inner_execute(tapes)
#     685     return post_processing(results)
#     687 _grad_on_execution = False
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\workflow\execution.py:283, in _make_inner_execute.<locals>.inner_execute(tapes, **_)
#     281 if numpy_only:
#     282     tapes = tuple(qml.transforms.convert_to_numpy_parameters(t) for t in tapes)
# --> 283 return cached_device_execution(tapes)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\workflow\execution.py:361, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     354     kwargs = {}
#     356 if cache is None or (isinstance(cache, bool) and not cache):
#     357     # No caching. Simply execute the execution function
#     358     # and return the results.
#     359
#     360     # must convert to list as new device interface returns tuples
# --> 361     res = list(fn(tapes, **kwargs))
#     362     return (res, []) if return_tuple else res
#     364 execution_tapes = {}
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:472, in QubitDevice.batch_execute(self, circuits)
#     467 for circuit in circuits:
#     468     # we need to reset the device here, else it will
#     469     # not start the next computation in the zero state
#     470     self.reset()
# --> 472     res = self.execute(circuit)
#     473     results.append(res)
#     475 if self.tracker.active:
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\devices\default_qubit_torch.py:245, in DefaultQubitTorch.execute(self, circuit, **kwargs)
#     237         if params_cuda_device != specified_device_cuda:
#     238             warnings.warn(
#     239                 f"Torch device {self._torch_device} specified "
#     240                 "upon PennyLane device creation does not match the "
#     241                 "Torch device of the gate parameters; "
#     242                 f"{self._torch_device} will be used."
#     243             )
# --> 245 return super().execute(circuit, **kwargs)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:302, in QubitDevice.execute(self, circuit, **kwargs)
#     299     results = self.shot_vec_statistics(circuit)
#     301 else:
# --> 302     results = self.statistics(circuit)
#     303     single_measurement = len(circuit.measurements) == 1
#     305     results = results[0] if single_measurement else tuple(results)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:643, in QubitDevice.statistics(self, circuit, shot_range, bin_size)
#     640 # 1. Based on the measurement type, compute statistics
#     641 # Pass instances directly
#     642 elif isinstance(m, ExpectationMP):
# --> 643     result = self.expval(obs, shot_range=shot_range, bin_size=bin_size)
#     645 elif isinstance(m, VarianceMP):
#     646     result = self.var(obs, shot_range=shot_range, bin_size=bin_size)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\devices\default_qubit_legacy.py:601, in DefaultQubitLegacy.expval(self, observable, shot_range, bin_size)
#     597 # intercept other Hamiltonians
#     598 # TODO: Ideally, this logic should not live in the Device, but be moved
#     599 # to a component that can be re-used by devices as needed.
#     600 if observable.name not in ("Hamiltonian", "SparseHamiltonian"):
# --> 601     return super().expval(observable, shot_range=shot_range, bin_size=bin_size)
#     603 assert self.shots is None, f"{observable.name} must be used with shots=None"
#     605 self.map_wires(observable.wires)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:1341, in QubitDevice.expval(self, observable, shot_range, bin_size)
#    1336 except qml.operation.EigvalsUndefinedError as e:
#    1337     raise qml.operation.EigvalsUndefinedError(
#    1338         f"Cannot compute analytic expectations of {observable.name}."
#    1339     ) from e
# -> 1341 prob = self.probability(wires=observable.wires)
#    1342 # In case of broadcasting, `prob` has two axes and this is a matrix-vector product
#    1343 return self._dot(prob, eigvals)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:1237, in QubitDevice.probability(self, wires, shot_range, bin_size)
#    1235 wires = wires or self.wires
#    1236 if self.shots is None:
# -> 1237     return self.analytic_probability(wires=wires)
#    1239 return self.estimate_probability(wires=wires, shot_range=shot_range, bin_size=bin_size)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\devices\default_qubit_legacy.py:962, in DefaultQubitLegacy.analytic_probability(self, wires)
#     960 real_state = self._real(flat_state)
#     961 imag_state = self._imag(flat_state)
# --> 962 return self.marginal_prob(real_state**2 + imag_state**2, wires)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\_qubit_device.py:1316, in QubitDevice.marginal_prob(self, prob, wires)
#    1314 prob = self._reshape(prob, shape)
#    1315 # sum over all inactive wires
# -> 1316 prob = self._reduce_sum(prob, inactive_device_wires)
#    1317 # rearrange wires to desired order
#    1318 prob = self._transpose(prob, desired_axes)
#
# File c:\Users\nicho\.pyenv\pyenv-win\versions\miniconda3-py310_23.1.0-1\envs\quantum\Lib\site-packages\pennylane\devices\default_qubit_torch.py:282, in DefaultQubitTorch._reduce_sum(array, axes)
#     280 if not axes:
#     281     return array
# --> 282 return torch.sum(array, dim=axes)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# plt.style.use("classic")
# plt.style.use("dark_background")

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, "b-", label="Train Loss")
plt.plot(epochs, test_loss, "r-", label="Test Loss")
plt.title("Train and Test Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_acc, "b-", label="Train Accuracy")
plt.plot(epochs, test_acc, "r-", label="Test Accuracy")
plt.title("Train and Test Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.tight_layout()
plt.show()
